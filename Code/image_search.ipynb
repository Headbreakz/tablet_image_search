# %%
import pandas as pd
df1=pd.read_excel('공공데이터개방_낱알식별목록_re.xlsx')
image=df1['큰제품이미지']
shape=df1['의약품제형']
color=df1['색상앞']
# image_name=df1['이미지이름']

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

for i in range(1,1001):

    img = cv2.imread('./image/'+str(i)+'.jpg')
    img = cv2.resize(img,dsize=(350,200),interpolation=cv2.INTER_LINEAR)
    mask = np.zeros(img.shape[:2],np.uint8)

    bgdModel = np.zeros((1,65),np.float64)
    fgdModel = np.zeros((1,65),np.float64)

    height,width,c= img.shape
    a = int(width*0.06)
    b = int(height*0.08)
    c = int(width*0.86)
    d = int(height*0.7)
    rect = (a,b,c,d)
    # rect = (box[0][0], box[0][1], box[0][2]-box[0][0], box[0][3]-box[0][1])
    cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

    mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
    img = img*mask2[:,:,np.newaxis]

#     plt.imshow(img),plt.colorbar(),plt.show()
    cv2.imwrite('./image_test/'+str(i)+'.jpg',img)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import os

root_dir='./image/'
save_dir='./image_backgroud_del/'
for (root,dirs,files) in os.walk(root_dir):
#     print(root[7:])
#     for dir_name in dirs :
#         print(dir_name)
    for file_name in files:
        print('{}/{}'.format(root,file_name))
# Out:
# ./image/rectangle_black/10097.jpg
# ./image/rectangle_black/10536.jpg
# ./image/rectangle_black/10585.jpg
# ./image/rectangle_black/11734.jpg
# ./image/rectangle_black/118.jpg
# ./image/rectangle_black/12017.jpg
# ./image/rectangle_black/1204.jpg
# ./image/rectangle_black/12680.jpg
# ./image/rectangle_black/13300.jpg
# ./image/rectangle_black/13610.jpg
# ./image/rectangle_black/13971.jpg
# ./image/rectangle_black/16930.jpg
# ./image/rectangle_black/17985.jpg
# ./image/rectangle_black/18389.jpg
# ./image/rectangle_black/18429.jpg
# ./image/rectangle_black/1881.jpg
# ./image/rectangle_black/2031.jpg
# ./image/rectangle_black/2369.jpg
# ./image/rectangle_black/2390.jpg
# ./image/rectangle_black/2689.jpg
# ./image/rectangle_black/3012.jpg
# ./image/rectangle_black/3271.jpg
# ./image/rectangle_black/4366.jpg
# ./image/rectangle_black/4570.jpg
# ./image/rectangle_black/4718.jpg
# ./image/rectangle_black/5107.jpg
# ./image/rectangle_black/5122.jpg
# ./image/rectangle_black/5350.jpg
# ...

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import os

root_dir='./image/'
save_dir='./image_backgroud_del/'
for (root,dirs,files) in os.walk(root_dir):
    for file_name in files:
        img = cv2.imread('{}/{}'.format(root,file_name))
        print('{}/{}'.format(root,file_name))
        img = cv2.resize(img,dsize=(350,200),interpolation=cv2.INTER_LINEAR)
        mask = np.zeros(img.shape[:2],np.uint8)

        bgdModel = np.zeros((1,65),np.float64)
        fgdModel = np.zeros((1,65),np.float64)

        height,width,c= img.shape
        a = int(width*0.06)
        b = int(height*0.08)
        c = int(width*0.86)
        d = int(height*0.7)
        rect = (a,b,c,d)
        # rect = (box[0][0], box[0][1], box[0][2]-box[0][0], box[0][3]-box[0][1])
        cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

        mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
        img = img*mask2[:,:,np.newaxis]

        if not(os.path.isdir("{}{}".format(save_dir,root[7:]))):
                    os.makedirs(os.path.join("{}{}".format(save_dir,root[7:])))

    #     plt.imshow(img),plt.colorbar(),plt.show()
        cv2.imwrite("{}{}/{}".format(save_dir,root[7:],file_name),img)
# Out:
# ./image/rectangle_white/1001.jpg
# ./image/rectangle_white/10046.jpg
# ./image/rectangle_white/10063.jpg
# ./image/rectangle_white/10065.jpg
# ./image/rectangle_white/10075.jpg
# ./image/rectangle_white/10079.jpg
# ./image/rectangle_white/10084.jpg
# ./image/rectangle_white/1009.jpg
# ./image/rectangle_white/10090.jpg
# ./image/rectangle_white/101.jpg
# ./image/rectangle_white/10105.jpg
# ./image/rectangle_white/10109.jpg
# ./image/rectangle_white/1011.jpg
# ./image/rectangle_white/10115.jpg
# ./image/rectangle_white/10116.jpg
# ./image/rectangle_white/1012.jpg
# ./image/rectangle_white/10129.jpg
# ./image/rectangle_white/10138.jpg
# ./image/rectangle_white/10150.jpg
# ./image/rectangle_white/10153.jpg
# ./image/rectangle_white/10160.jpg
# ./image/rectangle_white/10171.jpg
# ./image/rectangle_white/10175.jpg
# ./image/rectangle_white/10181.jpg
# ./image/rectangle_white/10193.jpg
# ./image/rectangle_white/10205.jpg
# ./image/rectangle_white/1022.jpg
# ...

# %%
import os

root_dir='./image_backgroud_del/'
save_dir='./final_image/'
for (root, dirs, files) in os.walk(root_dir):
    if len(files) > 0:
        for file_name in files:            
#             print("file: " + file_name)            
            print("{}/{}".format(root[21:],file_name[:-4])+'.png')
#             print("{}{}".format(save_dir,root[22:]))
#             print("{}{}/{}".format(save_dir,root[22:],file_name))
# Out:
# /a hemicyclea semicircle_green/3672.png
# /a hemicyclea semicircle_white/4270.png
# /circle_black/10777.png
# /circle_black/11943.png
# /circle_black/17345.png
# /circle_black/2996.png
# /circle_black/4968.png
# /circle_black/8541.png
# /circle_black/8691.png
# /circle_blue/1017.png
# /circle_blue/1021.png
# /circle_blue/10403.png
# /circle_blue/10502.png
# /circle_blue/10765.png
# /circle_blue/10802.png
# /circle_blue/10853.png
# /circle_blue/10882.png
# /circle_blue/11246.png
# /circle_blue/11381.png
# /circle_blue/11409.png
# /circle_blue/11502.png
# /circle_blue/11565.png
# /circle_blue/1167.png
# /circle_blue/11876.png
# /circle_blue/12014.png
# /circle_blue/12031.png
# /circle_blue/12073.png
# /circle_blue/1244.png
# /circle_blue/12465.png
# /circle_blue/1291.png
# /circle_blue/13110.png
# /circle_blue/13119.png
# /circle_blue/13493.png
# /circle_blue/13565.png
# /circle_blue/1371.png
# /circle_blue/13745.png
# /circle_blue/13890.png
# /circle_blue/1395.png
# ...

# %%
import numpy as np
import cv2
img = cv2.imread('./image/1.jpg')
mask = np.zeros(img.shape[:2],np.uint8)

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2BGRA)
# Out:
# (0, 0, 426, 780)

# %%
from PIL import Image
import numpy as np
import cv2
from matplotlib import pyplot as plt
import os

root_dir='./image_backgroud_del/'
save_dir='./final_image/'
for (root,dirs,files) in os.walk(root_dir):
    for file_name in files:
        im = Image.open('{}/{}'.format(root,file_name))
#         im.save(file_name[:-4]+'.png')
#         img = Image.open(file_name[:-4]+'.png')
        img = im.convert("RGBA")
        datas =img.getdata()
        newData = []
        cutOff = 50

        for item in datas:
            if item[0] < cutOff and item[1] < cutOff and item[2] < cutOff:
                newData.append((0, 0, 0, 0))
    #             RGB의 각 요소가 모두 cutOff 이상이면 transparent하게 바꿔줍니다.
            elif item[0] == 191 and item[1] == 206 and item[2] == 225:
                newData.append((0, 0, 0, 0))
            elif item[0] == 219 and item[1] == 211 and item[2] == 224:
                newData.append((0, 0, 0, 0))
            elif item[0] == 199 and item[1] == 191 and item[2] == 204:
                newData.append((0, 0, 0, 0))
            elif item[0] == 189 and item[1] == 205 and item[2] == 228:
                newData.append((0, 0, 0, 0))
            elif item[0] == 194 and item[1] == 206 and item[2] == 222:
                newData.append((0, 0, 0, 0))
    #         elif 185 <= item[0] and item[0] <= 220 and 185 <= item[1] and item[1] <= 210 and 200 <= item[2] and item[2] <= 225 :
    #             newData.append((0, 0, 0, 0))

            else:
                newData.append(item)
                # 나머지 요소는 변경하지 않습니다.
        img.putdata(newData)
        if not(os.path.isdir("{}{}".format(save_dir,root[22:]))):
                    os.makedirs(os.path.join("{}{}".format(save_dir,root[22:])))
        img.save("{}{}/{}.png".format(save_dir,root[22:],file_name[:-4]),"PNG")

# %%
import glob

images = glob.glob('./image/*.jpg')
print(images)
# Out:
# ['./image\\1.jpg', './image\\10.jpg', './image\\11.jpg', './image\\12.jpg', './image\\13.jpg', './image\\14.jpg', './image\\15.jpg', './image\\16.jpg', './image\\17.jpg', './image\\18.jpg', './image\\19.jpg', './image\\2.jpg', './image\\20.jpg', './image\\21.jpg', './image\\22.jpg', './image\\23.jpg', './image\\24.jpg', './image\\25.jpg', './image\\26.jpg', './image\\27.jpg', './image\\28.jpg', './image\\29.jpg', './image\\3.jpg', './image\\30.jpg', './image\\4.jpg', './image\\5.jpg', './image\\6.jpg', './image\\7.jpg', './image\\8.jpg', './image\\9.jpg']

# %%
im = Image.open('./image/1.jpg')
im.save('./image_test/1.png')
